# %%
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-5-e0f303203dcb> in <module>
#       6 pyp.style.use('fivethirtyeight')
#       7
# ----> 8 from IPyton.core.display import display, HTML
#       9 display(HTML("<sytle>div.output_scroll { height : 44em; }</style>"))
#
# ModuleNotFoundError: No module named 'IPyton'

# %%
import pandas as pd
import sqlite3
import math
import datetime
import numpy as np
import matplotlib.pyplot as plt

# %%
conn = sqlite3.connect('database.db')

# %%
c = conn.cursor()

# %%
df = pd.read_csv("perpus.csv")
df
# Out:
#     tahun  bulan       jenis                  perpustakaan  jumlah
# 0    2019      1  Pengunjung                        CIKINI    5797
# 1    2019      1  Pengunjung                      KUNINGAN    5191
# 2    2019      1  Pengunjung      KPAK Jakpus (Stationary)    2459
# 3    2019      1  Pengunjung         KPAK Jakpus (Pusling)    1509
# 4    2019      1  Pengunjung           KPAK Jakpus (RPTRA)   32754
# 5    2019      1  Pengunjung      KPAK Jaktim (Stationary)     582
# 6    2019      1  Pengunjung         KPAK Jaktim (Pusling)   27078
# 7    2019      1  Pengunjung           KPAK Jaktim (RPTRA)   32081
# 8    2019      1  Pengunjung      KPAK Jakbar (Stationary)    4523
# 9    2019      1  Pengunjung         KPAK Jakbar (Pusling)   19634
# 10   2019      1  Pengunjung           KPAK Jakbar (RPTRA)   43753
# 11   2019      1  Pengunjung      KPAK Jaksel (Stationary)    2155
# 12   2019      1  Pengunjung         KPAK Jaksel (Pusling)    8259
# ...
